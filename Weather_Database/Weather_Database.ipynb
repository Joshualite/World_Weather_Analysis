# %%
import pandas as pd
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests

# %%
lats = np.random.uniform(low = -90.000 , high = 90.000 , size = 2000)
lngs = np.random.uniform(low =-180.000 , high = 180.000, size = 2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mount gambier
# Processing Record 2 of Set 1 | kalemie
# Processing Record 3 of Set 1 | fortuna
# Processing Record 4 of Set 1 | alamos
# Processing Record 5 of Set 1 | maykain
# City not found. Skipping...
# Processing Record 6 of Set 1 | turukhansk
# Processing Record 7 of Set 1 | llanes
# Processing Record 8 of Set 1 | cabo san lucas
# Processing Record 9 of Set 1 | qaanaaq
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | jinxiang
# Processing Record 14 of Set 1 | yishui
# Processing Record 15 of Set 1 | saint george
# Processing Record 16 of Set 1 | agua dulce
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | harper
# Processing Record 19 of Set 1 | port lincoln
# Processing Record 20 of Set 1 | vina del mar
# Processing Record 21 of Set 1 | half moon bay
# Processing Record 22 of Set 1 | port blair
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | akranes
# Processing Record 25 of Set 1 | russell
# Processing Record 26 of Set 1 | moche
# Processing Record 27 of Set 1 | skjervoy
# Processing Record 28 of Set 1 | praia da vitoria
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | hasaki
# Processing Record 31 of Set 1 | sola
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | severo-kurilsk
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | mezhdurechensk
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | peleduy
# Processing Record 41 of Set 1 | necochea
# Processing Record 42 of Set 1 | puerto penasco
# Processing Record 43 of Set 1 | roebourne
# Processing Record 44 of Set 1 | swift current
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | lasa
# Processing Record 47 of Set 1 | tuatapere
# Processing Record 48 of Set 1 | khatanga
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | muisne
# Processing Record 1 of Set 2 | chuy
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | burnie
# Processing Record 4 of Set 2 | kahului
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | esperance
# Processing Record 7 of Set 2 | vanderhoof
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 2 | fereydun kenar
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | norman wells
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 15 of Set 2 | thinadhoo
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | mossendjo
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | emmett
# Processing Record 21 of Set 2 | svetlogorsk
# Processing Record 22 of Set 2 | montes altos
# Processing Record 23 of Set 2 | conde
# Processing Record 24 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | do rud
# City not found. Skipping...
# Processing Record 27 of Set 2 | kaihua
# Processing Record 28 of Set 2 | petropavlovka
# Processing Record 29 of Set 2 | lagoa
# Processing Record 30 of Set 2 | namatanai
# Processing Record 31 of Set 2 | hambantota
# Processing Record 32 of Set 2 | suzu
# City not found. Skipping...
# Processing Record 33 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 2 | arraial do cabo
# Processing Record 35 of Set 2 | bandarbeyla
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | novobiryusinskiy
# Processing Record 39 of Set 2 | sur
# Processing Record 40 of Set 2 | mitsamiouli
# Processing Record 41 of Set 2 | provideniya
# Processing Record 42 of Set 2 | port macquarie
# Processing Record 43 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 2 | khandyga
# Processing Record 45 of Set 2 | bethel
# Processing Record 46 of Set 2 | belmonte
# Processing Record 47 of Set 2 | east london
# Processing Record 48 of Set 2 | the valley
# Processing Record 49 of Set 2 | vila velha
# Processing Record 50 of Set 2 | mweka
# Processing Record 1 of Set 3 | gargzdai
# Processing Record 2 of Set 3 | forest grove
# Processing Record 3 of Set 3 | valdivia
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | namibe
# Processing Record 6 of Set 3 | luderitz
# Processing Record 7 of Set 3 | busselton
# Processing Record 8 of Set 3 | atuona
# Processing Record 9 of Set 3 | carmo
# Processing Record 10 of Set 3 | lompoc
# Processing Record 11 of Set 3 | avera
# Processing Record 12 of Set 3 | gurskoye
# City not found. Skipping...
# Processing Record 13 of Set 3 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 14 of Set 3 | guerrero negro
# Processing Record 15 of Set 3 | comodoro rivadavia
# Processing Record 16 of Set 3 | verkhnevilyuysk
# Processing Record 17 of Set 3 | hasilpur
# Processing Record 18 of Set 3 | chokurdakh
# Processing Record 19 of Set 3 | broken hill
# Processing Record 20 of Set 3 | ponta do sol
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | kendari
# Processing Record 23 of Set 3 | coquimbo
# Processing Record 24 of Set 3 | burns lake
# Processing Record 25 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 3 | goderich
# Processing Record 27 of Set 3 | romny
# Processing Record 28 of Set 3 | lorengau
# Processing Record 29 of Set 3 | broadstairs
# Processing Record 30 of Set 3 | te anau
# Processing Record 31 of Set 3 | coihaique
# Processing Record 32 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 3 | merauke
# Processing Record 34 of Set 3 | kabalo
# Processing Record 35 of Set 3 | kapaa
# Processing Record 36 of Set 3 | puerto ayora
# Processing Record 37 of Set 3 | san cristobal
# Processing Record 38 of Set 3 | okha
# Processing Record 39 of Set 3 | bluff
# Processing Record 40 of Set 3 | constitucion
# Processing Record 41 of Set 3 | orchard homes
# Processing Record 42 of Set 3 | tilichiki
# Processing Record 43 of Set 3 | leningradskiy
# Processing Record 44 of Set 3 | nam tha
# City not found. Skipping...
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | porto santo
# Processing Record 47 of Set 3 | upernavik
# Processing Record 48 of Set 3 | yellowknife
# Processing Record 49 of Set 3 | seymchan
# Processing Record 50 of Set 3 | freeport
# Processing Record 1 of Set 4 | shingu
# Processing Record 2 of Set 4 | vengurla
# Processing Record 3 of Set 4 | manakara
# Processing Record 4 of Set 4 | lusaka
# Processing Record 5 of Set 4 | husavik
# Processing Record 6 of Set 4 | college
# Processing Record 7 of Set 4 | shaunavon
# Processing Record 8 of Set 4 | iqaluit
# Processing Record 9 of Set 4 | marshfield
# Processing Record 10 of Set 4 | saint-philippe
# Processing Record 11 of Set 4 | izberbash
# Processing Record 12 of Set 4 | egvekinot
# Processing Record 13 of Set 4 | panindicuaro
# Processing Record 14 of Set 4 | pavilosta
# Processing Record 15 of Set 4 | thompson
# Processing Record 16 of Set 4 | diffa
# Processing Record 17 of Set 4 | nanortalik
# Processing Record 18 of Set 4 | kjollefjord
# Processing Record 19 of Set 4 | saldanha
# Processing Record 20 of Set 4 | finnsnes
# Processing Record 21 of Set 4 | hirara
# Processing Record 22 of Set 4 | tautira
# Processing Record 23 of Set 4 | cabedelo
# Processing Record 24 of Set 4 | vagur
# Processing Record 25 of Set 4 | hilo
# Processing Record 26 of Set 4 | mahibadhoo
# Processing Record 27 of Set 4 | avarua
# Processing Record 28 of Set 4 | ancud
# Processing Record 29 of Set 4 | northam
# Processing Record 30 of Set 4 | ilulissat
# Processing Record 31 of Set 4 | lakes entrance
# Processing Record 32 of Set 4 | baoqing
# Processing Record 33 of Set 4 | bereda
# Processing Record 34 of Set 4 | kralendijk
# Processing Record 35 of Set 4 | mandera
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | tiznit
# Processing Record 38 of Set 4 | susanville
# Processing Record 39 of Set 4 | atar
# Processing Record 40 of Set 4 | kodiak
# Processing Record 41 of Set 4 | bandrele
# Processing Record 42 of Set 4 | yarensk
# Processing Record 43 of Set 4 | teeli
# Processing Record 44 of Set 4 | port moresby
# Processing Record 45 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 46 of Set 4 | carupano
# Processing Record 47 of Set 4 | saint-jean-de-braye
# Processing Record 48 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 4 | meulaboh
# Processing Record 50 of Set 4 | abu samrah
# Processing Record 1 of Set 5 | san policarpo
# Processing Record 2 of Set 5 | olafsvik
# Processing Record 3 of Set 5 | araouane
# Processing Record 4 of Set 5 | cidreira
# Processing Record 5 of Set 5 | sindor
# Processing Record 6 of Set 5 | hue
# Processing Record 7 of Set 5 | ewa beach
# Processing Record 8 of Set 5 | katsuura
# Processing Record 9 of Set 5 | zhob
# Processing Record 10 of Set 5 | ust-omchug
# Processing Record 11 of Set 5 | sioux lookout
# Processing Record 12 of Set 5 | mabaruma
# Processing Record 13 of Set 5 | sredec
# City not found. Skipping...
# Processing Record 14 of Set 5 | cherskiy
# Processing Record 15 of Set 5 | houlton
# Processing Record 16 of Set 5 | chumikan
# Processing Record 17 of Set 5 | ugoofaaru
# Processing Record 18 of Set 5 | guaruja
# Processing Record 19 of Set 5 | iracoubo
# Processing Record 20 of Set 5 | aras
# Processing Record 21 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 22 of Set 5 | yumen
# Processing Record 23 of Set 5 | baykit
# Processing Record 24 of Set 5 | zemio
# Processing Record 25 of Set 5 | torbay
# Processing Record 26 of Set 5 | aklavik
# Processing Record 27 of Set 5 | yaan
# Processing Record 28 of Set 5 | saint-pierre
# Processing Record 29 of Set 5 | najran
# Processing Record 30 of Set 5 | bambous virieux
# Processing Record 31 of Set 5 | mukhen
# Processing Record 32 of Set 5 | point pedro
# Processing Record 33 of Set 5 | lang son
# Processing Record 34 of Set 5 | vanimo
# Processing Record 35 of Set 5 | fairbanks
# Processing Record 36 of Set 5 | rocha
# Processing Record 37 of Set 5 | sao filipe
# Processing Record 38 of Set 5 | luba
# Processing Record 39 of Set 5 | general pico
# Processing Record 40 of Set 5 | gorom-gorom
# Processing Record 41 of Set 5 | trincomalee
# Processing Record 42 of Set 5 | flinders
# Processing Record 43 of Set 5 | pisco
# Processing Record 44 of Set 5 | airai
# Processing Record 45 of Set 5 | ahipara
# Processing Record 46 of Set 5 | lincoln
# Processing Record 47 of Set 5 | morros
# Processing Record 48 of Set 5 | tateyama
# Processing Record 49 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 5 | salinopolis
# Processing Record 1 of Set 6 | damaturu
# Processing Record 2 of Set 6 | portland
# Processing Record 3 of Set 6 | souillac
# Processing Record 4 of Set 6 | qandala
# Processing Record 5 of Set 6 | sao joao da barra
# Processing Record 6 of Set 6 | pangnirtung
# Processing Record 7 of Set 6 | srandakan
# Processing Record 8 of Set 6 | payson
# Processing Record 9 of Set 6 | shorapani
# Processing Record 10 of Set 6 | vangaindrano
# Processing Record 11 of Set 6 | medenychi
# Processing Record 12 of Set 6 | turek
# Processing Record 13 of Set 6 | uhlove
# Processing Record 14 of Set 6 | nantucket
# Processing Record 15 of Set 6 | anadyr
# Processing Record 16 of Set 6 | clarence town
# Processing Record 17 of Set 6 | saint-louis
# Processing Record 18 of Set 6 | roald
# Processing Record 19 of Set 6 | vardo
# Processing Record 20 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 6 | salinas
# Processing Record 22 of Set 6 | kutum
# Processing Record 23 of Set 6 | ponta delgada
# Processing Record 24 of Set 6 | mahendranagar
# Processing Record 25 of Set 6 | nishihara
# Processing Record 26 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 27 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 6 | lampazos de naranjo
# Processing Record 29 of Set 6 | bud
# Processing Record 30 of Set 6 | grindavik
# Processing Record 31 of Set 6 | tezu
# Processing Record 32 of Set 6 | buribay
# Processing Record 33 of Set 6 | zhumadian
# Processing Record 34 of Set 6 | salalah
# Processing Record 35 of Set 6 | hobyo
# Processing Record 36 of Set 6 | nome
# Processing Record 37 of Set 6 | yuncheng
# Processing Record 38 of Set 6 | kumano
# Processing Record 39 of Set 6 | felanitx
# Processing Record 40 of Set 6 | sitka
# Processing Record 41 of Set 6 | sibolga
# Processing Record 42 of Set 6 | mago
# Processing Record 43 of Set 6 | boralday
# Processing Record 44 of Set 6 | vysokogornyy
# Processing Record 45 of Set 6 | tahta
# Processing Record 46 of Set 6 | salur
# Processing Record 47 of Set 6 | menemen
# Processing Record 48 of Set 6 | tual
# Processing Record 49 of Set 6 | barcelos
# Processing Record 50 of Set 6 | halifax
# Processing Record 1 of Set 7 | vestmanna
# Processing Record 2 of Set 7 | mancio lima
# Processing Record 3 of Set 7 | bosaso
# Processing Record 4 of Set 7 | nemuro
# Processing Record 5 of Set 7 | narsaq
# Processing Record 6 of Set 7 | gat
# Processing Record 7 of Set 7 | meybod
# Processing Record 8 of Set 7 | talaya
# Processing Record 9 of Set 7 | itumba
# Processing Record 10 of Set 7 | mora
# Processing Record 11 of Set 7 | klaksvik
# Processing Record 12 of Set 7 | pechenga
# Processing Record 13 of Set 7 | linqiong
# Processing Record 14 of Set 7 | daeni
# Processing Record 15 of Set 7 | lethem
# Processing Record 16 of Set 7 | elko
# Processing Record 17 of Set 7 | caxito
# Processing Record 18 of Set 7 | tiarei
# Processing Record 19 of Set 7 | bengkulu
# Processing Record 20 of Set 7 | faanui
# Processing Record 21 of Set 7 | mahebourg
# Processing Record 22 of Set 7 | gunjur
# Processing Record 23 of Set 7 | hofn
# Processing Record 24 of Set 7 | tartki
# City not found. Skipping...
# Processing Record 25 of Set 7 | poum
# Processing Record 26 of Set 7 | victoria
# Processing Record 27 of Set 7 | homer
# Processing Record 28 of Set 7 | san jose
# Processing Record 29 of Set 7 | las vegas
# Processing Record 30 of Set 7 | saint-augustin
# Processing Record 31 of Set 7 | mechetinskaya
# Processing Record 32 of Set 7 | balkanabat
# Processing Record 33 of Set 7 | kenai
# Processing Record 34 of Set 7 | sept-iles
# Processing Record 35 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 7 | ambilobe
# Processing Record 37 of Set 7 | tiksi
# Processing Record 38 of Set 7 | yizheng
# Processing Record 39 of Set 7 | turan
# Processing Record 40 of Set 7 | henties bay
# Processing Record 41 of Set 7 | san patricio
# Processing Record 42 of Set 7 | sharjah
# Processing Record 43 of Set 7 | axim
# Processing Record 44 of Set 7 | londoko
# Processing Record 45 of Set 7 | kindu
# Processing Record 46 of Set 7 | bathsheba
# Processing Record 47 of Set 7 | usinsk
# Processing Record 48 of Set 7 | laguna
# Processing Record 49 of Set 7 | ridgecrest
# Processing Record 50 of Set 7 | miranda
# Processing Record 1 of Set 8 | saint-georges
# Processing Record 2 of Set 8 | patratu
# City not found. Skipping...
# Processing Record 3 of Set 8 | kirakira
# Processing Record 4 of Set 8 | kruisfontein
# Processing Record 5 of Set 8 | butaritari
# Processing Record 6 of Set 8 | wana
# Processing Record 7 of Set 8 | forbes
# Processing Record 8 of Set 8 | dzilam gonzalez
# Processing Record 9 of Set 8 | puhja
# Processing Record 10 of Set 8 | dakar
# Processing Record 11 of Set 8 | rovaniemi
# Processing Record 12 of Set 8 | gravdal
# Processing Record 13 of Set 8 | collierville
# Processing Record 14 of Set 8 | pavlikeni
# Processing Record 15 of Set 8 | khuzdar
# Processing Record 16 of Set 8 | pudoc
# Processing Record 17 of Set 8 | dera bugti
# Processing Record 18 of Set 8 | pangai
# Processing Record 19 of Set 8 | mayo
# Processing Record 20 of Set 8 | hutchinson
# Processing Record 21 of Set 8 | kavieng
# Processing Record 22 of Set 8 | pregassona
# Processing Record 23 of Set 8 | cairns
# Processing Record 24 of Set 8 | lovington
# Processing Record 25 of Set 8 | clyde river
# Processing Record 26 of Set 8 | touros
# Processing Record 27 of Set 8 | makakilo city
# Processing Record 28 of Set 8 | porvoo
# Processing Record 29 of Set 8 | qaqortoq
# Processing Record 30 of Set 8 | verkhniy uslon
# Processing Record 31 of Set 8 | alugan
# Processing Record 32 of Set 8 | swellendam
# Processing Record 33 of Set 8 | yeletskiy
# City not found. Skipping...
# Processing Record 34 of Set 8 | xuddur
# Processing Record 35 of Set 8 | qasigiannguit
# Processing Record 36 of Set 8 | santa cruz
# Processing Record 37 of Set 8 | cananeia
# Processing Record 38 of Set 8 | kaitangata
# Processing Record 39 of Set 8 | hami
# Processing Record 40 of Set 8 | george
# Processing Record 41 of Set 8 | ciudad bolivar
# Processing Record 42 of Set 8 | bulungu
# Processing Record 43 of Set 8 | kalmunai
# Processing Record 44 of Set 8 | a
# City not found. Skipping...
# Processing Record 45 of Set 8 | mogadishu
# Processing Record 46 of Set 8 | aripuana
# Processing Record 47 of Set 8 | jardim
# Processing Record 48 of Set 8 | yulara
# Processing Record 49 of Set 8 | xinyu
# Processing Record 50 of Set 8 | montepuez
# Processing Record 1 of Set 9 | arlit
# Processing Record 2 of Set 9 | kyra
# Processing Record 3 of Set 9 | slave lake
# Processing Record 4 of Set 9 | hondo
# Processing Record 5 of Set 9 | reconquista
# Processing Record 6 of Set 9 | kushiro
# Processing Record 7 of Set 9 | rio grande
# Processing Record 8 of Set 9 | padang
# Processing Record 9 of Set 9 | alikalia
# Processing Record 10 of Set 9 | hengyang
# Processing Record 11 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 12 of Set 9 | mehamn
# Processing Record 13 of Set 9 | seguela
# Processing Record 14 of Set 9 | ketchikan
# Processing Record 15 of Set 9 | gornopravdinsk
# Processing Record 16 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 9 | rodrigues alves
# Processing Record 18 of Set 9 | mali
# Processing Record 19 of Set 9 | strezhevoy
# Processing Record 20 of Set 9 | phuthaditjhaba
# Processing Record 21 of Set 9 | kupang
# Processing Record 22 of Set 9 | moose factory
# Processing Record 23 of Set 9 | grand gaube
# Processing Record 24 of Set 9 | nyrob
# Processing Record 25 of Set 9 | korla
# Processing Record 26 of Set 9 | alofi
# Processing Record 27 of Set 9 | zeya
# Processing Record 28 of Set 9 | shyroke
# Processing Record 29 of Set 9 | wenatchee
# Processing Record 30 of Set 9 | garowe
# Processing Record 31 of Set 9 | bara
# Processing Record 32 of Set 9 | leirvik
# Processing Record 33 of Set 9 | charters towers
# Processing Record 34 of Set 9 | pacific grove
# Processing Record 35 of Set 9 | orodara
# Processing Record 36 of Set 9 | kibre mengist
# Processing Record 37 of Set 9 | komsomolskiy
# Processing Record 38 of Set 9 | ribeira grande
# Processing Record 39 of Set 9 | antofagasta
# Processing Record 40 of Set 9 | fort nelson
# Processing Record 41 of Set 9 | baft
# Processing Record 42 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 9 | palmer
# Processing Record 45 of Set 9 | kashary
# Processing Record 46 of Set 9 | cayenne
# Processing Record 47 of Set 9 | barra do bugres
# Processing Record 48 of Set 9 | mounana
# Processing Record 49 of Set 9 | shenjiamen
# Processing Record 50 of Set 9 | kovernino
# Processing Record 1 of Set 10 | nieuw amsterdam
# Processing Record 2 of Set 10 | rio gallegos
# Processing Record 3 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 10 | bloemfontein
# Processing Record 5 of Set 10 | muros
# Processing Record 6 of Set 10 | cordoba
# Processing Record 7 of Set 10 | carauari
# Processing Record 8 of Set 10 | kamaishi
# Processing Record 9 of Set 10 | bure
# Processing Record 10 of Set 10 | buchanan
# Processing Record 11 of Set 10 | ambon
# Processing Record 12 of Set 10 | oxford
# Processing Record 13 of Set 10 | kumylzhenskaya
# Processing Record 14 of Set 10 | osoyoos
# Processing Record 15 of Set 10 | bismarck
# Processing Record 16 of Set 10 | vila franca do campo
# Processing Record 17 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 18 of Set 10 | bobbili
# Processing Record 19 of Set 10 | srednekolymsk
# Processing Record 20 of Set 10 | revda
# Processing Record 21 of Set 10 | vari
# Processing Record 22 of Set 10 | benguela
# Processing Record 23 of Set 10 | sorsk
# Processing Record 24 of Set 10 | great falls
# Processing Record 25 of Set 10 | krasnoselkup
# Processing Record 26 of Set 10 | jizan
# Processing Record 27 of Set 10 | fethiye
# Processing Record 28 of Set 10 | buala
# Processing Record 29 of Set 10 | jamame
# Processing Record 30 of Set 10 | zavitinsk
# Processing Record 31 of Set 10 | metro
# Processing Record 32 of Set 10 | buraydah
# Processing Record 33 of Set 10 | foxton
# Processing Record 34 of Set 10 | illapel
# Processing Record 35 of Set 10 | la ronge
# Processing Record 36 of Set 10 | makubetsu
# Processing Record 37 of Set 10 | los llanos de aridane
# Processing Record 38 of Set 10 | eureka
# Processing Record 39 of Set 10 | sumbe
# Processing Record 40 of Set 10 | zyryanka
# Processing Record 41 of Set 10 | senmonorom
# City not found. Skipping...
# Processing Record 42 of Set 10 | sorland
# Processing Record 43 of Set 10 | alenquer
# Processing Record 44 of Set 10 | rantepao
# Processing Record 45 of Set 10 | horasan
# Processing Record 46 of Set 10 | santa isabel
# Processing Record 47 of Set 10 | olinda
# Processing Record 48 of Set 10 | dikson
# Processing Record 49 of Set 10 | shawnee
# Processing Record 50 of Set 10 | bakaly
# Processing Record 1 of Set 11 | zyryanovsk
# Processing Record 2 of Set 11 | richards bay
# Processing Record 3 of Set 11 | narimanov
# Processing Record 4 of Set 11 | codrington
# Processing Record 5 of Set 11 | pitimbu
# Processing Record 6 of Set 11 | rincon
# Processing Record 7 of Set 11 | asau
# Processing Record 8 of Set 11 | opuwo
# Processing Record 9 of Set 11 | mudon
# Processing Record 10 of Set 11 | canaries
# Processing Record 11 of Set 11 | bossangoa
# Processing Record 12 of Set 11 | orocue
# Processing Record 13 of Set 11 | ixtapa
# Processing Record 14 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 11 | berlevag
# Processing Record 16 of Set 11 | vilhena
# Processing Record 17 of Set 11 | haukipudas
# Processing Record 18 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 19 of Set 11 | dubenskiy
# City not found. Skipping...
# Processing Record 20 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 21 of Set 11 | dukat
# Processing Record 22 of Set 11 | nagai
# Processing Record 23 of Set 11 | bilma
# Processing Record 24 of Set 11 | mezen
# Processing Record 25 of Set 11 | naze
# Processing Record 26 of Set 11 | atocha
# Processing Record 27 of Set 11 | bukachacha
# Processing Record 28 of Set 11 | oinofita
# City not found. Skipping...
# Processing Record 29 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 30 of Set 11 | malbork
# Processing Record 31 of Set 11 | pilar
# Processing Record 32 of Set 11 | mastic beach
# Processing Record 33 of Set 11 | tura
# Processing Record 34 of Set 11 | rawson
# Processing Record 35 of Set 11 | letlhakeng
# Processing Record 36 of Set 11 | tottori
# Processing Record 37 of Set 11 | zigong
# Processing Record 38 of Set 11 | bukama
# Processing Record 39 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 40 of Set 11 | neepawa
# Processing Record 41 of Set 11 | nuristan
# Processing Record 42 of Set 11 | okhotsk
# Processing Record 43 of Set 11 | amapa
# Processing Record 44 of Set 11 | mishelevka
# Processing Record 45 of Set 11 | dali
# Processing Record 46 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 11 | phan thiet
# Processing Record 48 of Set 11 | iwanai
# Processing Record 49 of Set 11 | staraya poltavka
# Processing Record 50 of Set 11 | alamosa
# Processing Record 1 of Set 12 | talnakh
# Processing Record 2 of Set 12 | twin falls
# Processing Record 3 of Set 12 | lipin bor
# Processing Record 4 of Set 12 | roura
# Processing Record 5 of Set 12 | abashiri
# Processing Record 6 of Set 12 | morristown
# Processing Record 7 of Set 12 | glendive
# Processing Record 8 of Set 12 | praia
# Processing Record 9 of Set 12 | stawell
# Processing Record 10 of Set 12 | madison heights
# Processing Record 11 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 12 of Set 12 | moussoro
# Processing Record 13 of Set 12 | griffith
# Processing Record 14 of Set 12 | isetskoye
# Processing Record 15 of Set 12 | ternate
# Processing Record 16 of Set 12 | rockport
# Processing Record 17 of Set 12 | barquisimeto
# Processing Record 18 of Set 12 | kefamenanu
# Processing Record 19 of Set 12 | ulladulla
# Processing Record 20 of Set 12 | bardejov
# Processing Record 21 of Set 12 | gamba
# Processing Record 22 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 12 | ninghai
# Processing Record 25 of Set 12 | alpena
# Processing Record 26 of Set 12 | san joaquin
# Processing Record 27 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 28 of Set 12 | udachnyy
# Processing Record 29 of Set 12 | maragogi
# Processing Record 30 of Set 12 | vao
# Processing Record 31 of Set 12 | yamada
# Processing Record 32 of Set 12 | letterkenny
# Processing Record 33 of Set 12 | tirukkoyilur
# Processing Record 34 of Set 12 | bose
# Processing Record 35 of Set 12 | atasu
# Processing Record 36 of Set 12 | dudinka
# Processing Record 37 of Set 12 | rosario
# Processing Record 38 of Set 12 | mobaye
# Processing Record 39 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 40 of Set 12 | poya
# Processing Record 41 of Set 12 | nucsoara
# Processing Record 42 of Set 12 | mount isa
# Processing Record 43 of Set 12 | kununurra
# Processing Record 44 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 12 | pokhara
# Processing Record 46 of Set 12 | haradok
# Processing Record 47 of Set 12 | concepcion del oro
# Processing Record 48 of Set 12 | vanavara
# Processing Record 49 of Set 12 | walvis bay
# Processing Record 50 of Set 12 | salaga
# Processing Record 1 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 2 of Set 13 | mkushi
# Processing Record 3 of Set 13 | flin flon
# Processing Record 4 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 5 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 13 | visnes
# Processing Record 7 of Set 13 | antigonish
# Processing Record 8 of Set 13 | champerico
# Processing Record 9 of Set 13 | sar-e pul
# Processing Record 10 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 11 of Set 13 | faya
# Processing Record 12 of Set 13 | eydhafushi
# Processing Record 13 of Set 13 | mirnyy
# Processing Record 14 of Set 13 | qingdao
# Processing Record 15 of Set 13 | karaidel
# Processing Record 16 of Set 13 | askarovo
# Processing Record 17 of Set 13 | alzamay
# Processing Record 18 of Set 13 | kalabo
# Processing Record 19 of Set 13 | lucea
# Processing Record 20 of Set 13 | ergani
# Processing Record 21 of Set 13 | bolshaya atnya
# City not found. Skipping...
# Processing Record 22 of Set 13 | svetlaya
# Processing Record 23 of Set 13 | varhaug
# Processing Record 24 of Set 13 | idenao
# Processing Record 25 of Set 13 | mosquera
# Processing Record 26 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 13 | porto velho
# Processing Record 28 of Set 13 | kungurtug
# Processing Record 29 of Set 13 | azrow
# City not found. Skipping...
# Processing Record 30 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 13 | samagaltay
# Processing Record 32 of Set 13 | erenhot
# Processing Record 33 of Set 13 | jiaocheng
# Processing Record 34 of Set 13 | macia
# Processing Record 35 of Set 13 | geraldton
# Processing Record 36 of Set 13 | auki
# Processing Record 37 of Set 13 | omboue
# Processing Record 38 of Set 13 | honningsvag
# Processing Record 39 of Set 13 | pathein
# Processing Record 40 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 13 | nosy varika
# Processing Record 42 of Set 13 | willowmore
# Processing Record 43 of Set 13 | buenos aires
# Processing Record 44 of Set 13 | canton
# Processing Record 45 of Set 13 | caravelas
# Processing Record 46 of Set 13 | isangel
# Processing Record 47 of Set 13 | razole
# Processing Record 48 of Set 13 | lerwick
# Processing Record 49 of Set 13 | houston
# Processing Record 50 of Set 13 | haines junction
# Processing Record 1 of Set 14 | moroto
# Processing Record 2 of Set 14 | vostok
# Processing Record 3 of Set 14 | alice springs
# Processing Record 4 of Set 14 | kattivakkam
# Processing Record 5 of Set 14 | mantsala
# Processing Record 6 of Set 14 | gizo
# Processing Record 7 of Set 14 | poronaysk
# Processing Record 8 of Set 14 | wagar
# Processing Record 9 of Set 14 | marzuq
# Processing Record 10 of Set 14 | chokwe
# Processing Record 11 of Set 14 | mae sot
# Processing Record 12 of Set 14 | kedrovyy
# Processing Record 13 of Set 14 | turayf
# Processing Record 14 of Set 14 | san quintin
# Processing Record 15 of Set 14 | aketi
# Processing Record 16 of Set 14 | la romana
# Processing Record 17 of Set 14 | cartagena
# Processing Record 18 of Set 14 | paris
# Processing Record 19 of Set 14 | ambulu
# Processing Record 20 of Set 14 | beringovskiy
# Processing Record 21 of Set 14 | torres
# Processing Record 22 of Set 14 | kidodi
# Processing Record 23 of Set 14 | itarema
# Processing Record 24 of Set 14 | susanino
# Processing Record 25 of Set 14 | mehran
# Processing Record 26 of Set 14 | newcastle
# Processing Record 27 of Set 14 | korem
# Processing Record 28 of Set 14 | sao joao da boa vista
# Processing Record 29 of Set 14 | dingle
# Processing Record 30 of Set 14 | perth
# Processing Record 31 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 14 | bilibino
# Processing Record 33 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 14 | acarau
# Processing Record 35 of Set 14 | canico
# Processing Record 36 of Set 14 | xudat
# Processing Record 37 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 38 of Set 14 | victor harbor
# Processing Record 39 of Set 14 | baghdad
# Processing Record 40 of Set 14 | volchikha
# Processing Record 41 of Set 14 | morant bay
# Processing Record 42 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 14 | itabira
# Processing Record 44 of Set 14 | hay river
# Processing Record 45 of Set 14 | hailar
# Processing Record 46 of Set 14 | mpika
# Processing Record 47 of Set 14 | avon lake
# Processing Record 48 of Set 14 | ahuacatlan
# Processing Record 49 of Set 14 | lander
# Processing Record 50 of Set 14 | dhidhdhoo
# Processing Record 1 of Set 15 | mombetsu
# Processing Record 2 of Set 15 | monroe
# Processing Record 3 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 15 | fairlie
# Processing Record 5 of Set 15 | fenoarivo atsinanana
# Processing Record 6 of Set 15 | guiratinga
# Processing Record 7 of Set 15 | presidente dutra
# Processing Record 8 of Set 15 | kavaratti
# Processing Record 9 of Set 15 | nizhniy tsasuchey
# Processing Record 10 of Set 15 | mutata
# Processing Record 11 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 12 of Set 15 | lucapa
# Processing Record 13 of Set 15 | labuhan
# Processing Record 14 of Set 15 | lubaczow
# Processing Record 15 of Set 15 | paamiut
# Processing Record 16 of Set 15 | adrar
# Processing Record 17 of Set 15 | ambovombe
# Processing Record 18 of Set 15 | jatibonico
# Processing Record 19 of Set 15 | tapaua
# City not found. Skipping...
# Processing Record 20 of Set 15 | marathon
# Processing Record 21 of Set 15 | sambava
# Processing Record 22 of Set 15 | kamisu
# Processing Record 23 of Set 15 | ranong
# Processing Record 24 of Set 15 | guadalajara
# Processing Record 25 of Set 15 | itoman
# Processing Record 26 of Set 15 | tanete
# Processing Record 27 of Set 15 | wyndham
# Processing Record 28 of Set 15 | presidencia roque saenz pena
# Processing Record 29 of Set 15 | petukhovo
# Processing Record 30 of Set 15 | singojuruh
# Processing Record 31 of Set 15 | xichang
# Processing Record 32 of Set 15 | sainte-rose
# Processing Record 33 of Set 15 | ossora
# Processing Record 34 of Set 15 | sechura
# Processing Record 35 of Set 15 | ashqelon
# Processing Record 36 of Set 15 | kleck
# City not found. Skipping...
# Processing Record 37 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 38 of Set 15 | nuuk
# Processing Record 39 of Set 15 | wahiawa
# Processing Record 40 of Set 15 | zhigansk
# Processing Record 41 of Set 15 | dunedin
# Processing Record 42 of Set 15 | beruwala
# Processing Record 43 of Set 15 | pontianak
# Processing Record 44 of Set 15 | pochutla
# Processing Record 45 of Set 15 | seoul
# Processing Record 46 of Set 15 | langxiang
# Processing Record 47 of Set 15 | arinos
# Processing Record 48 of Set 15 | san martin
# Processing Record 49 of Set 15 | beloye
# Processing Record 50 of Set 15 | gorin
# Processing Record 1 of Set 16 | aksu
# Processing Record 2 of Set 16 | taft
# Processing Record 3 of Set 16 | dongning
# Processing Record 4 of Set 16 | rawannawi
# City not found. Skipping...
# Processing Record 5 of Set 16 | kailua
# Processing Record 6 of Set 16 | puerto escondido
# Processing Record 7 of Set 16 | martapura
# Processing Record 8 of Set 16 | neuquen
# Processing Record 9 of Set 16 | buluang
# Processing Record 10 of Set 16 | agropoli
# Processing Record 11 of Set 16 | jadu
# Processing Record 12 of Set 16 | brae
# Processing Record 13 of Set 16 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 14 of Set 16 | maumere
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Mount Gambier      AU -37.8333  140.7667     67.55        44           5
# 1        Kalemie      CD  -5.9475   29.1947     70.02        88         100
# 2        Fortuna      US  40.5982 -124.1573     61.36        68          90
# 3         Alamos      MX  27.0167 -108.9333     78.71        52         100
# 4     Turukhansk      RU  65.8167   87.9833      5.25        97          95
#
#    Wind Speed Current Description
# 0        1.81           clear sky
# 1        6.38          light rain
# 2        1.01     overcast clouds
# 3        3.67     overcast clouds
# 4        3.40     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
